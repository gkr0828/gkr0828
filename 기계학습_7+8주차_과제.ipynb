# %% [markdown]
# <a href="https://colab.research.google.com/github/gkr0828/gkr0828/blob/main/%EA%B8%B0%EA%B3%84%ED%95%99%EC%8A%B5_7%2B8%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
##데이터셋 로드
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # 4-1 가중치 초기화
# 1. he_uniform : 활성화 함수가 ReLU인 경우 사용
# 2. glorot_uniform : 활성화 함수가 Sigmoid, Taha 인 경우 사용

# %%
##가중치를 적용하지 않은 경우
model = tf.keras.Sequential ([tf.keras.layers.Flatten(input_shape=(28,28)),
                              tf.keras.layers.Dense(64, activation = 'relu'),
                              tf.keras.layers.Dense(32, activation = 'relu'),
                              tf.keras.layers.Dense(10, activation = 'softmax')])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 784)               0
#
#  dense_18 (Dense)            (None, 64)                50240
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  dense_20 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 52,650
# Trainable params: 52,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
##kernel_initializer = 'uniform'
dense = tf.keras.layers.Dense(256,kernel_initializer = 'uniform',activation='relu')

# %%
##kernel_initializer = 'normal'
dense = tf.keras.layers.Dense(256,kernel_initializer = 'normal',activation='relu')

# %%
##kernel_initializer = 'he_normal'
dense = tf.keras.layers.Dense(256,kernel_initializer = 'he_normal',activation='relu')

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6442 - accuracy: 0.7851 - val_loss: 0.4912 - val_accuracy: 0.8784
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4110 - accuracy: 0.8936 - val_loss: 0.3580 - val_accuracy: 0.9151
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2695 - accuracy: 0.9292 - val_loss: 0.2667 - val_accuracy: 0.9297
# Epoch 4/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2086 - accuracy: 0.9422 - val_loss: 0.2328 - val_accuracy: 0.9404
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1766 - accuracy: 0.9524 - val_loss: 0.2221 - val_accuracy: 0.9444
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1488 - accuracy: 0.9591 - val_loss: 0.2100 - val_accuracy: 0.9467
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1364 - accuracy: 0.9632 - val_loss: 0.1702 - val_accuracy: 0.9571
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1271 - accuracy: 0.9656 - val_loss: 0.1535 - val_accuracy: 0.9620
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1126 - accuracy: 0.9690 - val_loss: 0.1927 - val_accuracy: 0.9565
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1092 - accuracy: 0.9696 - val_loss: 0.1584 - val_accuracy: 0.9607

# %%
##kernel_initializer = 'he_normal' 을 적용한 경우
model_w_he = tf.keras.Sequential ([tf.keras.layers.Flatten(input_shape=(28,28)),
                              tf.keras.layers.Dense(64, kernel_initializer = 'he_normal', activation = 'relu'),
                              tf.keras.layers.Dense(32, activation = 'relu'),
                              tf.keras.layers.Dense(10, activation = 'softmax')])
model_w_he.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 784)               0
#
#  dense_24 (Dense)            (None, 64)                50240
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dense_26 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 52,650
# Trainable params: 52,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_w_he.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_w_he = model_w_he.fit(x_train, y_train, validation_data=(x_test, y_test),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4788 - accuracy: 0.7237 - val_loss: 0.5417 - val_accuracy: 0.8679
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4226 - accuracy: 0.8899 - val_loss: 0.3552 - val_accuracy: 0.9053
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2839 - accuracy: 0.9229 - val_loss: 0.2658 - val_accuracy: 0.9364
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2210 - accuracy: 0.9395 - val_loss: 0.2018 - val_accuracy: 0.9452
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1733 - accuracy: 0.9504 - val_loss: 0.1835 - val_accuracy: 0.9528
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1526 - accuracy: 0.9572 - val_loss: 0.1691 - val_accuracy: 0.9558
# Epoch 7/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1332 - accuracy: 0.9625 - val_loss: 0.1773 - val_accuracy: 0.9538
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1182 - accuracy: 0.9674 - val_loss: 0.1837 - val_accuracy: 0.9540
# Epoch 9/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1134 - accuracy: 0.9691 - val_loss: 0.1526 - val_accuracy: 0.9631
# Epoch 10/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1042 - accuracy: 0.9712 - val_loss: 0.1471 - val_accuracy: 0.9640

# %%
#두 모델 비교 시작화
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,11),history.history['val_loss'], color = 'navy', label = 'None')
plt.plot(np.arange(1,11),history_w_he.history['val_loss'], color = 'red', label = 'He Initialization')
plt.title("Losses", fontsize = 22)
plt.xlabel('epochs')
plt.ylabel("Losses")
plt.legend()
plt.show()

# %%
##kernel_initializer = 'glorot_normal' 을 적용한 경우
model_w_gl = tf.keras.Sequential ([tf.keras.layers.Flatten(input_shape=(28,28)),
                              tf.keras.layers.Dense(64, kernel_initializer = 'glorot_normal', activation = 'sigmoid'),
                              tf.keras.layers.Dense(32, activation = 'sigmoid'),
                              tf.keras.layers.Dense(10, activation = 'softmax')])
model_w_gl.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_8 (Flatten)         (None, 784)               0
#
#  dense_27 (Dense)            (None, 64)                50240
#
#  dense_28 (Dense)            (None, 32)                2080
#
#  dense_29 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 52,650
# Trainable params: 52,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_w_gl.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_w_gl = model_w_gl.fit(x_train, y_train, validation_data = (x_test, y_test), epochs =10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.8045 - accuracy: 0.7961 - val_loss: 0.4592 - val_accuracy: 0.8659
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.4044 - accuracy: 0.8808 - val_loss: 0.3828 - val_accuracy: 0.8898
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3764 - accuracy: 0.8866 - val_loss: 0.3658 - val_accuracy: 0.8911
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3460 - accuracy: 0.8952 - val_loss: 0.3320 - val_accuracy: 0.8993
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3355 - accuracy: 0.8971 - val_loss: 0.2996 - val_accuracy: 0.9062
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3096 - accuracy: 0.9052 - val_loss: 0.2929 - val_accuracy: 0.9102
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2968 - accuracy: 0.9087 - val_loss: 0.2939 - val_accuracy: 0.9100
# Epoch 8/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2908 - accuracy: 0.9115 - val_loss: 0.3114 - val_accuracy: 0.9050
# Epoch 9/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.2983 - accuracy: 0.9090 - val_loss: 0.2809 - val_accuracy: 0.9111
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2837 - accuracy: 0.9128 - val_loss: 0.2737 - val_accuracy: 0.9171

# %%
#세 모델 시각화
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,11),history.history['val_loss'], color = 'navy', label = 'None')
plt.plot(np.arange(1,11),history_w_he.history['val_loss'], color = 'red', label = 'He Initialization')
plt.plot(np.arange(1,11),history_w_gl.history['val_loss'], color = 'green', label = 'Xavier Initialization')
plt.title("Losses", fontsize = 22)
plt.xlabel('epochs')
plt.ylabel("Losses")
plt.legend()
plt.show()

# %% [markdown]
# # 4-2 규제(Regularization)
#
#
# 1. L1 : 가중치의 절대값에 0.001을 곱하여 비용 추가
# 2. L2 : 가중치의 제곱에 0.001을 곱하여 비용 추가

# %%
regularizer2 = tf.keras.regularizers.l2(0.001)
L2_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(64,kernel_initializer='normal', kernel_regularizer = regularizer2, activation='relu'),
    tf.keras.layers.Dense(32,kernel_initializer='normal', kernel_regularizer = regularizer2, activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax'),
])

# %%
L2_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
L2_model = L2_model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.7800 - accuracy: 0.8500 - val_loss: 0.3465 - val_accuracy: 0.9359
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3120 - accuracy: 0.9377 - val_loss: 0.2595 - val_accuracy: 0.9501
# Epoch 3/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2386 - accuracy: 0.9527 - val_loss: 0.2440 - val_accuracy: 0.9497
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2133 - accuracy: 0.9579 - val_loss: 0.2234 - val_accuracy: 0.9554
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1921 - accuracy: 0.9631 - val_loss: 0.2002 - val_accuracy: 0.9624
# Epoch 6/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1851 - accuracy: 0.9651 - val_loss: 0.2198 - val_accuracy: 0.9575
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1788 - accuracy: 0.9666 - val_loss: 0.2060 - val_accuracy: 0.9605
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1770 - accuracy: 0.9673 - val_loss: 0.1871 - val_accuracy: 0.9655
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1726 - accuracy: 0.9689 - val_loss: 0.1942 - val_accuracy: 0.9638
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1731 - accuracy: 0.9687 - val_loss: 0.1947 - val_accuracy: 0.9649

# %%
#L1 규제
regularizer1 = tf.keras.regularizers.l1(0.001)
L1_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(64,kernel_initializer='normal', kernel_regularizer = regularizer1, activation='relu'),
    tf.keras.layers.Dense(32,kernel_initializer='normal', kernel_regularizer = regularizer1, activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax'),
])

# %%
L1_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
L1_model = L1_model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 1.6425 - accuracy: 0.8600 - val_loss: 0.9001 - val_accuracy: 0.9254
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7142 - accuracy: 0.9301 - val_loss: 0.5939 - val_accuracy: 0.9337
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5065 - accuracy: 0.9409 - val_loss: 0.4900 - val_accuracy: 0.9415
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4546 - accuracy: 0.9453 - val_loss: 0.4592 - val_accuracy: 0.9468
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4310 - accuracy: 0.9474 - val_loss: 0.4030 - val_accuracy: 0.9550
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4089 - accuracy: 0.9498 - val_loss: 0.4076 - val_accuracy: 0.9479
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3945 - accuracy: 0.9508 - val_loss: 0.3774 - val_accuracy: 0.9537
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3920 - accuracy: 0.9505 - val_loss: 0.3963 - val_accuracy: 0.9503
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3884 - accuracy: 0.9523 - val_loss: 0.3897 - val_accuracy: 0.9523
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3786 - accuracy: 0.9530 - val_loss: 0.3715 - val_accuracy: 0.9545

# %%
#L2 규제 모델비교 시각화
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,11),history.history['val_loss'], color = 'navy', label = 'None')
plt.plot(np.arange(1,11),L2_model.history['val_loss'], color = 'red', label = 'L2 Regularization')
plt.plot(np.arange(1,11),L1_model.history['val_loss'], color = 'green', label = 'L1 Regularization')
plt.title("Losses", fontsize = 22)
plt.xlabel('epochs')
plt.ylabel("Losses")
plt.legend()
plt.show()

# %% [markdown]
# # 4-3 드롭아웃(Drop Out)
#
#
# 1. 비율로 로드수를 줄이는 규제 방법

# %%
#L1(0.01)+Dropout(0.5)
regularizer1 = tf.keras.regularizers.l1(0.001)
drop_model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),    
    tf.keras.layers.Dense(64,kernel_initializer='normal', kernel_regularizer = regularizer1, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(32,kernel_initializer='normal', kernel_regularizer = regularizer1, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10,activation='softmax'),
])
drop_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_11 (Flatten)        (None, 784)               0
#
#  dense_36 (Dense)            (None, 64)                50240
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_37 (Dense)            (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_38 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 52,650
# Trainable params: 52,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
drop_model = drop_model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 3.5458 - accuracy: 0.2306 - val_loss: 2.1405 - val_accuracy: 0.5492
# Epoch 2/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 2.1430 - accuracy: 0.4039 - val_loss: 1.3446 - val_accuracy: 0.6772
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.7017 - accuracy: 0.4902 - val_loss: 1.1422 - val_accuracy: 0.7314
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.5466 - accuracy: 0.5447 - val_loss: 0.8860 - val_accuracy: 0.8578
# Epoch 5/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 1.3936 - accuracy: 0.6275 - val_loss: 0.8546 - val_accuracy: 0.8778
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.3027 - accuracy: 0.6712 - val_loss: 0.8211 - val_accuracy: 0.8697
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.2287 - accuracy: 0.7032 - val_loss: 0.7550 - val_accuracy: 0.9055
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1826 - accuracy: 0.7330 - val_loss: 0.7376 - val_accuracy: 0.9022
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1489 - accuracy: 0.7534 - val_loss: 0.7117 - val_accuracy: 0.9093
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 1.1227 - accuracy: 0.7656 - val_loss: 0.7300 - val_accuracy: 0.8996

# %%
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,11),history.history['val_loss'], color = 'navy', label = 'None')
plt.plot(np.arange(1,11),drop_model.history['val_loss'], color = 'red', label = 'L1+Dropout')
plt.plot(np.arange(1,11),L1_model.history['val_loss'], color = 'green', label = 'L1')
plt.title("Losses", fontsize = 22)
plt.xlabel('epochs')
plt.ylabel("Losses")
plt.legend()
plt.show()

# %% [markdown]
# # 4-4 배치 정규화(Batch Normanlization)
#
#
# 1. 각 층에서 스케일을 조정

# %%
batch_model = tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),    
                            tf.keras.layers.Dense(64, activation='relu'),
                            tf.keras.layers.BatchNormalization(),
                            tf.keras.layers.Dense(32, activation='relu'),
                            tf.keras.layers.BatchNormalization(),
                            tf.keras.layers.Dense(10,activation='softmax')])

# %%
batch_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
batch_model = batch_model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.3039 - accuracy: 0.9128 - val_loss: 0.1594 - val_accuracy: 0.9525
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1481 - accuracy: 0.9560 - val_loss: 0.1147 - val_accuracy: 0.9655
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1171 - accuracy: 0.9640 - val_loss: 0.1001 - val_accuracy: 0.9686
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0989 - accuracy: 0.9693 - val_loss: 0.0960 - val_accuracy: 0.9709
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0845 - accuracy: 0.9733 - val_loss: 0.0923 - val_accuracy: 0.9717
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0783 - accuracy: 0.9750 - val_loss: 0.0891 - val_accuracy: 0.9733
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0695 - accuracy: 0.9777 - val_loss: 0.0918 - val_accuracy: 0.9716
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0647 - accuracy: 0.9799 - val_loss: 0.0858 - val_accuracy: 0.9730
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0574 - accuracy: 0.9818 - val_loss: 0.0793 - val_accuracy: 0.9767
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0555 - accuracy: 0.9824 - val_loss: 0.0831 - val_accuracy: 0.9759

# %%
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,11),history.history['val_loss'], color = 'navy', label = 'None')
plt.plot(np.arange(1,11),batch_model.history['val_loss'], color = 'red', label = 'BatchNormal+ReLU')
plt.title("Losses", fontsize = 22)
plt.xlabel('epochs')
plt.ylabel("Losses")
plt.legend()
plt.show()

# %% [markdown]
# #4-5 활성화 함수
# 1.   ReLU
# 2.   Leaky ReLU

# %%
#Batch Normalization + LeakyReLU
Leaky_model = tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),    
                            tf.keras.layers.Dense(64),
                            tf.keras.layers.BatchNormalization(),
                            tf.keras.layers.LeakyReLU(alpha=0.5),
                            tf.keras.layers.Dense(32),
                            tf.keras.layers.BatchNormalization(),
                            tf.keras.layers.LeakyReLU(alpha=0.5),                           
                            tf.keras.layers.Dense(10,activation='softmax')])

# %%
Leaky_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
Leaky_model = Leaky_model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3605 - accuracy: 0.8965 - val_loss: 0.2285 - val_accuracy: 0.9289
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2201 - accuracy: 0.9353 - val_loss: 0.1706 - val_accuracy: 0.9467
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1782 - accuracy: 0.9462 - val_loss: 0.1551 - val_accuracy: 0.9541
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1545 - accuracy: 0.9530 - val_loss: 0.1391 - val_accuracy: 0.9585
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1420 - accuracy: 0.9557 - val_loss: 0.1229 - val_accuracy: 0.9607
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1309 - accuracy: 0.9598 - val_loss: 0.1106 - val_accuracy: 0.9663
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1206 - accuracy: 0.9617 - val_loss: 0.1126 - val_accuracy: 0.9662
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1134 - accuracy: 0.9637 - val_loss: 0.1086 - val_accuracy: 0.9660
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1067 - accuracy: 0.9656 - val_loss: 0.1105 - val_accuracy: 0.9665
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1025 - accuracy: 0.9674 - val_loss: 0.1228 - val_accuracy: 0.9641

# %%
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,11),history.history['val_loss'], color = 'navy', label = 'ReLU')
plt.plot(np.arange(1,11),batch_model.history['val_loss'], color = 'red', label = 'BatchNormal+ReLU')
plt.plot(np.arange(1,11),Leaky_model.history['val_loss'], color = 'green', label = 'BatchNormal+LeakyReLU')
plt.title("Losses", fontsize = 22)
plt.xlabel('epochs')
plt.ylabel("Losses")
plt.legend()
plt.show()
